# %% [markdown]
# # Templating ZTF alerts

# %%
import matplotlib

# For plots
font = {
    'weight': 'bold',
    'size': 22
}

matplotlib.rc('font', **font)

# Bands
filter_color = {1: '#1f77b4', 2: '#ff7f0e', 3: '#2ca02c'}
# [
#     '#1f77b4',  # muted blue
#     '#ff7f0e',  # safety orange
#     '#2ca02c',  # cooked asparagus green
#     '#d62728',  # brick red
#     '#9467bd',  # muted purple
#     '#8c564b',  # chestnut brown
#     '#e377c2',  # raspberry yogurt pink
#     '#7f7f7f',  # middle gray
#     '#bcbd22',  # curry yellow-green
#     '#17becf'   # blue-teal
# ]
filter_name = {1: 'g band', 2: 'r band', 3: 'i band'}

# %% [markdown]
# ## Reading ZTF alerts
#
# Let's first read bunch of ZTF alerts (from January 13 2020)

# %%
from fink_client.avroUtils import AlertReader

# Generic reader for Avro files
# You can also specify a single file
r = AlertReader('../sampledata')

# Materialize data as a Pandas DataFrame
alerts = r.to_pandas()

# %% [markdown]
# Let's see what in our alerts

# %%
alerts.head()
# Out:
#   schemavsn  ...                                   cutoutDifference
# 0       3.3  ...  {'fileName': 'candid1107083294115015013_pid110...
# 1       3.3  ...  {'fileName': 'candid1107088094015015006_pid110...
# 2       3.3  ...  {'fileName': 'candid1107085322515015001_pid110...
# 3       3.3  ...  {'fileName': 'candid1107083292715010005_pid110...
# 4       3.3  ...  {'fileName': 'candid1107082845215010048_pid110...
#
# [5 rows x 9 columns]

# %% [markdown]
# The first field of interest for us is `candidate` that contains the data for the measurement

# %%
# Each row is a dictionary
alerts['candidate'].head()
# Out:
# 0    {'jd': 2458861.5832986, 'fid': 2, 'pid': 11070...
# 1    {'jd': 2458861.5880903, 'fid': 1, 'pid': 11070...
# 2    {'jd': 2458861.5853241, 'fid': 1, 'pid': 11070...
# 3    {'jd': 2458861.5832986, 'fid': 2, 'pid': 11070...
# 4    {'jd': 2458861.5828472, 'fid': 2, 'pid': 11070...
# Name: candidate, dtype: object

# %% [markdown]
# The other field is `prv_candidates` that contains the history of the alerts over a period of 30 days

# %%
# Each row is a list of dictionary
alerts['prv_candidates'].head()
# Out:
# 0    [{'jd': 2458835.5740856, 'fid': 2, 'pid': 1081...
# 1    [{'jd': 2458833.6249306, 'fid': 1, 'pid': 1079...
# 2    [{'jd': 2458837.5841204, 'fid': 2, 'pid': 1083...
# 3    [{'jd': 2458835.5740856, 'fid': 2, 'pid': 1081...
# 4    [{'jd': 2458833.5703356, 'fid': 2, 'pid': 1079...
# Name: prv_candidates, dtype: object

# %% [markdown]
# Let's focus on one single alert for this exercise:

# %%
# Let's take the third alert
alert = r.to_list(10)[2]
alert
# Out:
# {'schemavsn': '3.3',
#  'publisher': 'ZTF (www.ztf.caltech.edu)',
#  'objectId': 'ZTF18abscgeq',
#  'candid': 1107085322515015001,
#  'candidate': {'jd': 2458861.5853241,
#   'fid': 1,
#   'pid': 1107085322515,
#   'diffmaglim': 18.73360252380371,
#   'pdiffimfilename': 'ztf_20200113085139_000245_zg_c07_o_q2_scimrefdiffimg.fits',
#   'programpi': 'Kulkarni',
#   'programid': 1,
#   'candid': 1107085322515015001,
#   'isdiffpos': 't',
#   'tblid': 1,
#   'nid': 1107,
#   'rcid': 25,
#   'field': 245,
#   'xpos': 1822.921875,
#   'ypos': 1768.196044921875,
#   'ra': 359.5918753,
#   'dec': -24.8280199,
#   'magpsf': 16.61745262145996,
#   'sigmapsf': 0.04210016876459122,
#   'chipsf': 4.0542192459106445,
#   'magap': 16.67329978942871,
#   'sigmagap': 0.031599998474121094,
#   'distnr': 0.093686543405056,
#   'magnr': 16.395999908447266,
#   'sigmagnr': 0.014000000432133675,
#   'chinr': 0.5270000100135803,
#   'sharpnr': -0.03700000047683716,
#   'sky': -0.3241316080093384,
#   'magdiff': 0.05584700033068657,
#   'fwhm': 4.869999885559082,
#   'classtar': 0.9829999804496765,
#   'mindtoedge': 1249.578125,
#   'magfromlim': 2.0603017807006836,
#   'seeratio': 0.9923408031463623,
#   'aimage': 1.531000018119812,
#   'bimage': 1.4559999704360962,
#   'aimagerat': 0.3143737018108368,
#   'bimagerat': 0.29897329211235046,
#   'elong': 1.0515109300613403,
#   'nneg': 0,
#   'nbad': 0,
#   'rb': 0.7099999785423279,
#   'ssdistnr': -999.0,
#   'ssmagnr': -999.0,
#   'ssnamenr': 'null',
#   'sumrat': 1.0,
#   'magapbig': 16.658000946044922,
#   'sigmagapbig': 0.03929999843239784,
#   'ranr': 359.5918673,
#   'decnr': -24.8279945,
#   'sgmag1': 16.628000259399414,
#   'srmag1': 16.424400329589844,
#   'simag1': 16.33839988708496,
#   'szmag1': 16.23430061340332,
#   'sgscore1': 1.0,
#   'distpsnr1': 0.06796476989984512,
#   'ndethist': 94,
#   'ncovhist': 147,
#   'jdstarthist': 2458361.8970255,
#   'jdendhist': 2458861.5853241,
#   'scorr': 25.0393600463867,
#   'tooflag': 0,
#   'objectidps1': 78203595918826729,
#   'objectidps2': 78203595973604042,
#   'sgmag2': 21.104000091552734,
#   'srmag2': -999.0,
#   'simag2': 21.698200225830078,
#   'szmag2': -999.0,
#   'sgscore2': 0.1857219934463501,
#   'distpsnr2': 19.903518676757812,
#   'objectidps3': 78193595884989526,
#   'sgmag3': 21.994800567626953,
#   'srmag3': 21.61400032043457,
#   'simag3': 21.440399169921875,
#   'szmag3': -999.0,
#   'sgscore3': 0.701295018196106,
#   'distpsnr3': 24.07753562927246,
#   'nmtchps': 3,
#   'rfid': 245120125,
#   'jdstartref': 2458313.980521,
#   'jdendref': 2458351.900556,
#   'nframesref': 15,
#   'rbversion': 't17_f5_c3',
#   'dsnrms': 15.736324310302734,
#   'ssnrms': 56.722129821777344,
#   'dsdiff': -40.98580551147461,
#   'magzpsci': 26.118452072143555,
#   'magzpsciunc': 0.00011218240251764655,
#   'magzpscirms': 0.045903999358415604,
#   'nmatches': 102,
#   'clrcoeff': -0.07174000144004822,
#   'clrcounc': 0.0002837342908605933,
#   'zpclrcov': -0.00016387000505346805,
#   'zpmed': 26.075000762939453,
#   'clrmed': 0.5,
#   'clrrms': 0.24862700700759888,
#   'neargaia': 0.0667753592133522,
#   'neargaiabright': -999.0,
#   'maggaia': 16.112855911254883,
#   'maggaiabright': -999.0,
#   'exptime': 30.0,
#   'drb': 0.9892482757568359,
#   'drbversion': 'd6_m7'},
#  'prv_candidates': [{'jd': 2458837.5841204,
#    'fid': 2,
#    'pid': 1083084122515,
#    'diffmaglim': 19.601699829101562,
#    'pdiffimfilename': '/ztf/archive/sci/2019/1220/083796/ztf_20191220083796_000245_zr_c07_o_q2_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': 1083084122515015003,
#    'isdiffpos': 't',
#    'tblid': 3,
#    'nid': 1083,
#    'rcid': 25,
#    'field': 245,
#    'xpos': 1820.9599609375,
#    'ypos': 1777.1199951171875,
#    'ra': 359.5918684,
#    'dec': -24.8280638,
#    'magpsf': 17.666099548339844,
#    'sigmapsf': 0.056804999709129333,
#    'chipsf': 1.3634699583053589,
#    'magap': 17.617000579833984,
#    'sigmagap': 0.05169999971985817,
#    'distnr': 0.21028399467468262,
#    'magnr': 16.22599983215332,
#    'sigmagnr': 0.017999999225139618,
#    'chinr': 1.0019999742507935,
#    'sharpnr': -0.032999999821186066,
#    'sky': -0.1833609938621521,
#    'magdiff': -0.04913400113582611,
#    'fwhm': 2.049999952316284,
#    'classtar': 0.9700000286102295,
#    'mindtoedge': 1251.5400390625,
#    'magfromlim': 1.9846899509429932,
#    'seeratio': 1.5851500034332275,
#    'aimage': 1.1039999723434448,
#    'bimage': 0.996999979019165,
#    'aimagerat': 0.5385370254516602,
#    'bimagerat': 0.4863409996032715,
#    'elong': 1.107319951057434,
#    'nneg': 0,
#    'nbad': 0,
#    'rb': 0.9271429777145386,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': 1.0,
#    'magapbig': 17.599000930786133,
#    'sigmagapbig': 0.06350000202655792,
#    'ranr': 359.5918759,
#    'decnr': -24.828005,
#    'scorr': 10.0283,
#    'magzpsci': 26.258100509643555,
#    'magzpsciunc': 1.7752499843481928e-05,
#    'magzpscirms': 0.02987780049443245,
#    'clrcoeff': 0.11391100287437439,
#    'clrcounc': 2.7099800718133338e-05,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2458837.6072685,
#    'fid': 1,
#    'pid': 1083107262515,
#    'diffmaglim': 19.81679916381836,
#    'pdiffimfilename': '/ztf/archive/sci/2019/1220/107269/ztf_20191220107269_000245_zg_c07_o_q2_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1083,
#    'rcid': 25,
#    'field': 245,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 26.170000076293945,
#    'magzpsciunc': 2.5415900381631218e-05,
#    'magzpscirms': 0.034849900752305984,
#    'clrcoeff': -0.053882699459791183,
#    'clrcounc': 4.259679917595349e-05,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2458840.5929398,
#    'fid': 2,
#    'pid': 1086092932515,
#    'diffmaglim': 15.389399528503418,
#    'pdiffimfilename': '/ztf/archive/sci/2019/1223/092940/ztf_20191223092940_000245_zr_c07_o_q2_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1086,
#    'rcid': 25,
#    'field': 245,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 22.513999938964844,
#    'magzpsciunc': 0.0020508200395852327,
#    'magzpscirms': 0.028104199096560478,
#    'clrcoeff': 0.35400399565696716,
#    'clrcounc': 0.003958490211516619,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2458847.5761921,
#    'fid': 2,
#    'pid': 1093076192515,
#    'diffmaglim': 18.37969970703125,
#    'pdiffimfilename': '/ztf/archive/sci/2019/1230/076192/ztf_20191230076192_000245_zr_c07_o_q2_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': 1093076192515010049,
#    'isdiffpos': 'f',
#    'tblid': 49,
#    'nid': 1093,
#    'rcid': 25,
#    'field': 245,
#    'xpos': 1826.81005859375,
#    'ypos': 1785.1199951171875,
#    'ra': 359.5918959,
#    'dec': -24.8280652,
#    'magpsf': 17.6294002532959,
#    'sigmapsf': 0.07978600263595581,
#    'chipsf': 1.6759999990463257,
#    'magap': 18.04960060119629,
#    'sigmagap': 0.28189998865127563,
#    'distnr': 0.22340300679206848,
#    'magnr': 16.22599983215332,
#    'sigmagnr': 0.017999999225139618,
#    'chinr': 1.0019999742507935,
#    'sharpnr': -0.032999999821186066,
#    'sky': 0.1866849958896637,
#    'magdiff': 0.4201970100402832,
#    'fwhm': 1.271530032157898,
#    'classtar': 0.7210000157356262,
#    'mindtoedge': 1245.68994140625,
#    'magfromlim': 0.33013400435447693,
#    'seeratio': 2.0,
#    'aimage': 0.5929999947547913,
#    'bimage': 0.578000009059906,
#    'aimagerat': 0.4663679897785187,
#    'bimagerat': 0.454571008682251,
#    'elong': 1.0259499549865723,
#    'nneg': 8,
#    'nbad': 0,
#    'rb': 0.5814290046691895,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': 0.7605370283126831,
#    'magapbig': 18.05660057067871,
#    'sigmagapbig': 0.36390000581741333,
#    'ranr': 359.5918759,
#    'decnr': -24.828005,
#    'scorr': 8.22,
#    'magzpsci': 25.598400115966797,
#    'magzpsciunc': 0.000251095014391467,
#    'magzpscirms': 0.10818400233983994,
#    'clrcoeff': 0.10317300260066986,
#    'clrcounc': 0.0003925240016542375,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2458851.5823958,
#    'fid': 2,
#    'pid': 1097082392515,
#    'diffmaglim': 16.938899993896484,
#    'pdiffimfilename': '/ztf/archive/sci/2020/0103/082396/ztf_20200103082396_000245_zr_c07_o_q2_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1097,
#    'rcid': 25,
#    'field': 245,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 24.741100311279297,
#    'magzpsciunc': 0.00019482499919831753,
#    'magzpscirms': 0.03900830075144768,
#    'clrcoeff': 0.060206398367881775,
#    'clrcounc': 0.0003495700075291097,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2458851.6060185,
#    'fid': 1,
#    'pid': 1097106012515,
#    'diffmaglim': 17.440099716186523,
#    'pdiffimfilename': '/ztf/archive/sci/2020/0103/105845/ztf_20200103105845_000245_zg_c07_o_q2_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': None,
#    'isdiffpos': None,
#    'tblid': None,
#    'nid': 1097,
#    'rcid': 25,
#    'field': 245,
#    'xpos': None,
#    'ypos': None,
#    'ra': None,
#    'dec': None,
#    'magpsf': None,
#    'sigmapsf': None,
#    'chipsf': None,
#    'magap': None,
#    'sigmagap': None,
#    'distnr': None,
#    'magnr': None,
#    'sigmagnr': None,
#    'chinr': None,
#    'sharpnr': None,
#    'sky': None,
#    'magdiff': None,
#    'fwhm': None,
#    'classtar': None,
#    'mindtoedge': None,
#    'magfromlim': None,
#    'seeratio': None,
#    'aimage': None,
#    'bimage': None,
#    'aimagerat': None,
#    'bimagerat': None,
#    'elong': None,
#    'nneg': None,
#    'nbad': None,
#    'rb': None,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': None,
#    'magapbig': None,
#    'sigmagapbig': None,
#    'ranr': None,
#    'decnr': None,
#    'scorr': None,
#    'magzpsci': 24.853200912475586,
#    'magzpsciunc': 0.000776456028688699,
#    'magzpscirms': 0.060936201363801956,
#    'clrcoeff': -0.060518499463796616,
#    'clrcounc': 0.0022244900465011597,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2458854.6066088,
#    'fid': 2,
#    'pid': 1100106602515,
#    'diffmaglim': 18.993000030517578,
#    'pdiffimfilename': '/ztf/archive/sci/2020/0106/106597/ztf_20200106106597_000245_zr_c07_o_q2_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': 1100106602515010014,
#    'isdiffpos': 'f',
#    'tblid': 14,
#    'nid': 1100,
#    'rcid': 25,
#    'field': 245,
#    'xpos': 1828.550048828125,
#    'ypos': 1756.3199462890625,
#    'ra': 359.5919436,
#    'dec': -24.828322,
#    'magpsf': 18.679800033569336,
#    'sigmapsf': 0.2447029948234558,
#    'chipsf': 1.447409987449646,
#    'magap': 19.44300079345703,
#    'sigmagap': 0.36410000920295715,
#    'distnr': 1.1475000381469727,
#    'magnr': 16.22599983215332,
#    'sigmagnr': 0.017999999225139618,
#    'chinr': 1.0019999742507935,
#    'sharpnr': -0.032999999821186066,
#    'sky': -0.14715799689292908,
#    'magdiff': 0.7632330060005188,
#    'fwhm': 2.0647099018096924,
#    'classtar': 0.8640000224113464,
#    'mindtoedge': 1243.949951171875,
#    'magfromlim': -0.4499650001525879,
#    'seeratio': 2.0,
#    'aimage': 0.8840000033378601,
#    'bimage': 0.7910000085830688,
#    'aimagerat': 0.4281480014324188,
#    'bimagerat': 0.38310500979423523,
#    'elong': 1.1175700426101685,
#    'nneg': 3,
#    'nbad': 0,
#    'rb': 0.4942860007286072,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': 1.0,
#    'magapbig': 19.397199630737305,
#    'sigmagapbig': 0.44440001249313354,
#    'ranr': 359.5918759,
#    'decnr': -24.828005,
#    'scorr': 5.34822,
#    'magzpsci': 26.242799758911133,
#    'magzpsciunc': 5.240500104264356e-05,
#    'magzpscirms': 0.04812860116362572,
#    'clrcoeff': 0.1284410059452057,
#    'clrcounc': 8.178580173989758e-05,
#    'rbversion': 't17_f5_c3'},
#   {'jd': 2458861.5819329,
#    'fid': 2,
#    'pid': 1107081932515,
#    'diffmaglim': 18.635000228881836,
#    'pdiffimfilename': '/ztf/archive/sci/2020/0113/081586/ztf_20200113081586_000245_zr_c07_o_q2_scimrefdiffimg.fits.fz',
#    'programpi': 'Kulkarni',
#    'programid': 1,
#    'candid': 1107081932515015007,
#    'isdiffpos': '1',
#    'tblid': 7,
#    'nid': 1107,
#    'rcid': 25,
#    'field': 245,
#    'xpos': 1814.8299560546875,
#    'ypos': 1769.43994140625,
#    'ra': 359.5918254,
#    'dec': -24.828028,
#    'magpsf': 16.82349967956543,
#    'sigmapsf': 0.055024001747369766,
#    'chipsf': 2.809839963912964,
#    'magap': 16.9468994140625,
#    'sigmagap': 0.05090000107884407,
#    'distnr': 0.1820710003376007,
#    'magnr': 16.22599983215332,
#    'sigmagnr': 0.017999999225139618,
#    'chinr': 1.0019999742507935,
#    'sharpnr': -0.032999999821186066,
#    'sky': -0.3749450147151947,
#    'magdiff': 0.12343399971723557,
#    'fwhm': 3.930000066757202,
#    'classtar': 0.9829999804496765,
#    'mindtoedge': 1257.6700439453125,
#    'magfromlim': 1.6881099939346313,
#    'seeratio': 1.0495699644088745,
#    'aimage': 1.3179999589920044,
#    'bimage': 1.2280000448226929,
#    'aimagerat': 0.3353689908981323,
#    'bimagerat': 0.3124679923057556,
#    'elong': 1.0732899904251099,
#    'nneg': 0,
#    'nbad': 0,
#    'rb': 0.8257139921188354,
#    'ssdistnr': None,
#    'ssmagnr': None,
#    'ssnamenr': None,
#    'sumrat': 1.0,
#    'magapbig': 16.86039924621582,
#    'sigmagapbig': 0.05990000069141388,
#    'ranr': 359.5918759,
#    'decnr': -24.828005,
#    'scorr': 29.7334,
#    'magzpsci': 26.206499099731445,
#    'magzpsciunc': 5.106089884066023e-05,
#    'magzpscirms': 0.0413363017141819,
#    'clrcoeff': 0.12939999997615814,
#    'clrcounc': 8.646659989608452e-05,
#    'rbversion': 't17_f5_c3'}],
#  'cutoutScience': {'fileName': 'candid1107085322515015001_pid1107085322515_targ_sci.fits.gz',
#   'stampData': b'\x1f\x8b\x08\x
# %%
from fink_client.visualisation import extract_field

import matplotlib.pyplot as plt
import numpy as np

def plot_lightcurve(alert_dic: dict) -> None:
    """
    """
    # extract current and historical data as one vector
    mag = extract_field(alert_dic, 'magpsf')
    error = extract_field(alert_dic, 'sigmapsf')
    upper = extract_field(alert_dic, "diffmaglim")
    
    # filter bands
    fid = extract_field(alert_dic, "fid")
    
    # Rescale dates to end at 0
    jd = extract_field(alert_dic, "jd")
    dates = np.array([i - jd[0] for i in jd])

    # Title of the plot (alert ID)
    title = alert["objectId"]

    # loop over filters
    fig = plt.figure(figsize=(12,4))
    
    # Loop over each filter
    for filt in filter_color.keys():
        mask = np.where(fid == filt)[0]
        
        # Skip if no data
        if len(mask) == 0:
            continue

        # y data
        maskNotNone = mag[mask] != None
        plt.errorbar(
            dates[mask][maskNotNone], mag[mask][maskNotNone], yerr=error[mask][maskNotNone], 
            color=filter_color[filt], marker='o', ls='', label=filter_name[filt], mew=4)
        # Upper limits
        plt.plot(
            dates[mask][~maskNotNone], upper[mask][~maskNotNone], 
            color=filter_color[filt], marker='v', ls='', mew=4, alpha=0.5)
        plt.title(title)
    plt.legend()
    plt.gca().invert_yaxis()
    plt.xlabel('Days to candidate')
    plt.ylabel('Difference magnitude')
    plt.show()

# %% [markdown]
# Notice that we focus on `magpsf` and `sigmapsf` - these are the magnitude and error that you want to replace.

# %%
plot_lightcurve(alert)

# %% [markdown]
# ## Replacing alert data, and saving
#
# Let's replace our alert data, and saving the new alert on disk. We need to replace at least the current measurement, and the previous measurements.

# %%
n_historical_measurements = len(alert['prv_candidates'])
print('{} historical measurements'.format(n_historical_measurements))

# Generate fake data over new historical days
jd_min = np.min([alert['prv_candidates'][i]['jd'] for i in range(n_historical_measurements)])
jd_max = alert['candidate']['jd']
print('Historical measurements between {} and {}'.format(jd_min, jd_max))
# Out:
# 8 historical measurements
# Historical measurements between 2458837.5841204 and 2458861.5853241

# %% [markdown]
# Let's put new measurements - beware change in-place! We also do it for different filter bands

# %%
[
    alert['prv_candidates'][i].update({'magpsf': 20}) 
    if alert['prv_candidates'][i]['fid'] == 1
    else alert['prv_candidates'][i].update({'magpsf': 19}) 
    for i in range(n_historical_measurements)
]

[
    alert['prv_candidates'][i].update({'sigmapsf': 3}) 
    for i in range(n_historical_measurements) 
]

[
    alert['prv_candidates'][i].update({'diffmaglim': None}) 
    for i in range(n_historical_measurements) 
]

alert['candidate'].update({'magpsf': 15})  
alert['candidate'].update({'sigmapsf': 2})

# %%
plot_lightcurve(alert)

# %% [markdown]
# Of course, one could take into account other alert parameters - but I guess you have the idea! Finally save your new alert:

# %%
from fink_client.avroUtils import write_alert
from fink_client.avroUtils import _get_alert_schema

schema = _get_alert_schema()

# In this routine, the output filename is not an option
# Do not hesitate to change this routine if you want another output filename.
write_alert(alert, schema, path='.', overwrite=True)

# %% [markdown]
# Et voilà!

# %%
# !ls
# Out:
# Untitled.ipynb    ZTF18abscgeq.avro
